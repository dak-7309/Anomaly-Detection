# %% [markdown]
# <a href="https://colab.research.google.com/github/sanchit2843/Videoclassification/blob/master/videodata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Upload kaggle.json file
# !pip install -i https://test.pypi.org/simple/ supportlib
import supportlib.gettingdata as getdata
getdata.kaggle()
# !kaggle datasets download -d mission-ai/crimeucfdataset
getdata.zipextract('/content/crimeucfdataset.zip')

# %%
# !sudo apt-get install -y python-dev pkg-config
# !sudo apt-get install -y \
#     libavformat-dev libavcodec-dev libavdevice-dev \
#     libavutil-dev libswscale-dev libswresample-dev libavfilter-dev
# !pip3 install av

import av
import glob
import os
import time
from tqdm import tqdm
import datetime
import argparse
import cv2

# %%
def video_to_frame(path,out_path):
    vidcap = cv2.VideoCapture(path)
    success,image = vidcap.read()
    count = 0
    while success:
      cv2.imwrite(os.path.join(out_path,"{}.jpg".format(count)), image)
      success,image = vidcap.read()
      count += 1

# %%
def extract_frames(video_path):
    frames = []
    video = av.open(video_path)
    for frame in video.decode(0):
        yield frame.to_image()

# %%
path = '/home/iiitd/Anomaly_Dataset/Anomaly_Videos/Anomaly-Videos-Part-2/Burglary/Burglary001_x264.mp4'
result = '/home/iiitd/DDDD'


os.makedirs(result,exist_ok = True)


for j, frame in enumerate((extract_frames(path))):
    frame.save(os.path.join(result, f"{j}.jpg"))
# Out:
# stream 0, timescale not set

# %%
#Anomaly videos part1
path = '/home/iiitd/Anomaly_Dataset/Anomaly_Videos/Anomaly-Videos-Part-1'
result = '/home/iiitd/Dataset'

for i in os.listdir(path):
# for i in os.listdir(path):
  p1 = os.path.join(path,i)
  r1 = os.path.join(result,i)
  if os.path.exists(r1):
            continue
  os.makedirs(r1,exist_ok = True)
  for j in tqdm(os.listdir(p1)):
    vid_path = os.path.join(p1,j)
    r2 = os.path.join(r1,j[:-4])
    os.makedirs(r2,exist_ok = True)
    for j, frame in enumerate((extract_frames(vid_path))):
        frame.save(os.path.join(r2, f"{j}.jpg"))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]stream 0, timescale not set
#   2%|▏         | 1/50 [00:03<03:03,  3.74s/it]stream 0, timescale not set
#   4%|▍         | 2/50 [01:02<29:03, 36.32s/it]stream 0, timescale not set
#   6%|▌         | 3/50 [01:08<17:21, 22.17s/it]stream 0, timescale not set
#   8%|▊         | 4/50 [01:14<12:19, 16.08s/it]stream 0, timescale not set
#  10%|█         | 5/50 [01:27<10:59, 14.65s/it]stream 0, timescale not set
#  12%|█▏        | 6/50 [01:33<08:38, 11.79s/it]stream 0, timescale not set
#  14%|█▍        | 7/50 [01:48<09:12, 12.86s/it]stream 0, timescale not set
#  16%|█▌        | 8/50 [01:53<07:12, 10.30s/it]stream 0, timescale not set
#  18%|█▊        | 9/50 [02:12<08:55, 13.05s/it]stream 0, timescale not set
#  20%|██        | 10/50 [02:15<06:43, 10.10s/it]stream 0, timescale not set
#  22%|██▏       | 11/50 [02:20<05:31,  8.51s/it]stream 0, timescale not set
#  24%|██▍       | 12/50 [02:41<07:49, 12.35s/it]stream 0, timescale not set
#  26%|██▌       | 13/50 [03:29<14:14, 23.11s/it]stream 0, timescale not set
#  28%|██▊       | 14/50 [03:34<10:33, 17.61s/it]stream 0, timescale not set
#  30%|███       | 15/50 [03:59<11:35, 19.86s/it]stream 0, timescale not set
#  32%|███▏      | 16/50 [04:19<11:10, 19.73s/it]stream 0, timescale not set
#  34%|███▍      | 17/50 [04:23<08:22, 15.22s/it]stream 0, timescale not set
#  36%|███▌      | 18/50 [04:33<07:17, 13.66s/it]stream 0, timescale not set
#  38%|███▊      | 19/50 [04:48<07:10, 13.88s/it]stream 0, timescale not set
#  40%|████      | 20/50 [04:55<05:55, 11.86s/it]stream 0, timescale not set
#  42%|████▏     | 21/50 [04:57<04:16,  8.83s/it]stream 0, timescale not set
#  44%|████▍     | 22/50 [05:04<03:50,  8.25s/it]stream 0, timescale not set
#  46%|████▌     | 23/50 [05:32<06:25, 14.27s/it]stream 0, timescale not set
#  48%|████▊     | 24/50 [05:56<07:30, 17.33s/it]stream 0, timescale not set
#  50%|█████     | 25/50 [06:07<06:22, 15.31s/it]stream 0, timescale not set
#  52%|█████▏    | 26/50 [06:09<04:31, 11.33s/it]stream 0, timescale not set
#  54%|█████▍    | 27/50 [06:50<07:48, 20.36s/it]stream 0, timescale not set
#  56%|█████▌    | 28/50 [07:04<06:46, 18.47s/it]stream 0, timescale not set
#  58%|█████▊    | 29/50 [07:16<05:46, 16.50s/it]stream 0, timescale not set
#  60%|██████    | 30/50 [08:47<12:55, 38.79s/it]stream 0, timescale not set
#  62%|██████▏   | 31/50 [08:54<09:13, 29.14s/it]stream 0, timescale not set
#  64%|██████▍   | 32/50 [08:58<06:30, 21.67s/it]stream 0, timescale not set
#  66%|██████▌   | 33/50 [09:48<08:30, 30.02s/it]stream 0, timescale not set
#  68%|██████▊   | 34/50 [09:52<05:57, 22.34s/it]stream 0, timescale not set
#  70%|███████   | 35/50 [09:55<04:07, 16.48s/it]stream 0, timescale not set
#  72%|███████▏  | 36/50 [10:09<03:41, 15.86s/it]stream 0, timescale not set
#  74%|███████▍  | 37/50 [10:16<02:50, 13.10s/it]stream 0, timescale not set
#  76%|███████▌  | 38/50 [10:27<02:30, 12.55s/it]stream 0, timescale not set
#  78%|███████▊  | 39/50 [10:42<02:24, 13.13s/it]stream 0, timescale not set
#  80%|████████  | 40/50 [10:44<01:40, 10.06s/it]stream 0, timescale not set
#  82%|████████▏ | 41/50 [11:00<01:44, 11.56s/it]stream 0, timescale not set
#  84%|████████▍ | 42/50 [11:17<01:47, 13.46s/it]deprecated pixel format used, make sure you did set range correctly
#  86%|████████▌ | 43/50 [11:31<01:34, 13.51s/it]deprecated pixel format used, make sure you did set range correctly
#  (repeated 2449 more times)
# stream 0, timescale not set
#  88%|████████▊ | 44/50 [11:35<01:03, 10.51s/it]stream 0, timescale not set
#  90%|█████████ | 45/50 [11:40<00:45,  9.03s/it]stream 0, timescale not set
#  92%|█████████▏| 46/50 [11:55<00:42, 10.63s/it]stream 0, timescale not set
#  94%|█████████▍| 47/50 [11:55<00:23,  7.70s/it]stream 0, timescale not set
#  96%|█████████▌| 48/50 [12:11<00:20, 10.09s/it]stream 0, timescale not set
#  98%|█████████▊| 49/50 [12:15<00:08,  8.11s/it]stream 0, timescale not set
# 100%|██████████| 50/50 [13:08<00:00, 15.78s/it]
#   0%|          | 0/50 [00:00<?, ?it/s]deprecated pixel format used, make sure you did set range correctly
#   2%|▏         | 1/50 [00:44<36:11, 44.32s/it]deprecated pixel format used, make sure you did set range correctly
#  (repeated 7110 more times)
# stream 0, timescale not set
#   4%|▍         | 2/50 [00:54<19:12, 24.00s/it]stream 0, timescale not set
#   6%|▌         | 3/50 [01:03<13:31, 17.27s/it]stream 0, timescale not set
#   8%|▊         | 4/50 [01:15<11:39, 15.20s/it]stream 0, timescale not set
#  10%|█         | 5/50 [02:01<19:49, 26.43s/it]stream 0, timescale not set
#  12%|█▏        | 6/50 [02:21<17:46, 24.25s/it]stream 0, timescale not set
#  14%|█▍        | 7/50 [02:31<14:01, 19.57s/it]stream 0, timescale not set
#  16%|█▌        | 8/50 [02:50<13:33, 19.38s/it]stream 0, timescale not set
#  18%|█▊        | 9/50 [04:34<31:21, 45.90s/it]stream 0, timescale not set
#  20%|██        | 10/50 [04:51<24:35, 36.89s/it]stream 0, timescale not set
#  22%|██▏       | 11/50 [05:30<24:20, 37.46s/it]stream 0, timescale not set
#  24%|██▍       | 12/50 [05:41<18:33, 29.31s/it]stream 0, timescale not set
#  26%|██▌       | 13/50 [05:55<15:22, 24.93s/it]stream 0, timescale not set
#  28%|██▊       | 14/50 [06:22<15:18, 25.52s/it]stream 0, timescale not set
#  30%|███       | 15/50 [06:33<12:19, 21.12s/it]stream 0, timescale not set
#  32%|███▏      | 16/50 [06:50<11:17, 19.94s/it]stream 0, timescale not set
#  34%|███▍      | 17/50 [07:05<10:05, 18.36s/it]stream 0, timescale not set
#  36%|███▌      | 18/50 [07:10<07:42, 14.47s/it]stream 0, timescale not set
#  38%|███▊      | 19/50 [07:30<08:16, 16.00s/it]stream 0, timescale not set
#  40%|████      | 20/50 [08:11<11:49, 23.63s/it]stream 0, timescale not set
#  42%|████▏     | 21/50 [08:21<09:26, 19.54s/it]stream 0, timescale not set
#  44%|████▍     | 22/50 [09:31<16:03, 34.42s/it]stream 0, timescale not set
#  46%|████▌     | 23/50 [09:41<12:15, 27.26s/it]stream 0, timescale not set
#  48%|████▊     | 24/50 [09:50<09:25, 21.75s/it]stream 0, timescale not set
#  50%|█████     | 25/50 [16:30<56:17, 135.10s/it]stream 0, timescale not set
#  52%|█████▏    | 26/50 [16:44<39:35, 99.00s/it] stream 0, timescale not set
#  54%|█████▍    | 27/50 [16:53<27:35, 71.97s/it]stream 0, timescale not set
#  56%|█████▌    | 28/50 [17:43<23:54, 65.21s/it]stream 0, timescale not set
#  58%|█████▊    | 29/50 [18:20<19:55, 56.92s/it]stream 0, timescale not set
#  60%|██████    | 30/50 [18:28<14:05, 42.30s/it]stream 0, timescale not set
#  62%|██████▏   | 31/50 [19:28<15:04, 47.58s/it]stream 0, timescale not set
#  64%|██████▍   | 32/50 [19:34<10:31, 35.10s/it]stream 0, timescale not set
#  68%|██████▊   | 34/50 [20:51<10:36, 39.75s/it]stream 0, timescale not set
#  70%|███████   | 35/50 [21:42<10:46, 43.11s/it]stream 0, timescale not set
#  72%|███████▏  | 36/50 [21:59<08:14, 35.31s/it]stream 0, timescale not set
#  74%|███████▍  | 37/50 [22:12<06:10, 28.51s/it]stream 0, timescale not set
#  76%|███████▌  | 38/50 [22:35<05:20, 26.70s/it]stream 0, timescale not set
#  78%|███████▊  | 39/50 [22:56<04:37, 25.23s/it]stream 0, timescale not set
#  80%|████████  | 40/50 [23:12<03:44, 22.48s/it]stream 0, timescale not set
#  82%|████████▏ | 41/50 [23:31<03:11, 21.28s/it]stream 0, timescale not set
#  84%|████████▍ | 42/50 [24:52<05:14, 39.27s/it]stream 0, timescale not set
#  86%|████████▌ | 43/50 [25:02<03:33, 30.46s/it]stream 0, timescale not set
#  88%|████████▊ | 44/50 [25:24<02:47, 28.00s/it]stream 0, timescale not set
#  90%|█████████ | 45/50 [26:32<03:19, 39.92s/it]stream 0, timescale not set
#  92%|█████████▏| 46/50 [27:09<02:36, 39.13s/it]stream 0, timescale not set
#  94%|█████████▍| 47/50 [27:43<01:52, 37.61s/it]stream 0, timescale not set
#  96%|█████████▌| 48/50 [28:31<01:21, 40.65s/it]stream 0, timescale not set
#  98%|█████████▊| 49/50 [30:16<00:59, 59.96s/it]stream 0, timescale not set
# 100%|██████████| 50/50 [30:37<00:00, 36.74s/it]
#   0%|          | 0/50 [00:00<?, ?it/s]stream 0, timescale not set
#   2%|▏         | 1/50 [00:35<28:45, 35.21s/it]stream 0, timescale not set
#   4%|▍         | 2/50 [00:39<13:29, 16.87s/it]stream 0, timescale not set
#   6%|▌         | 3/50 [01:17<20:57, 26.75s/it]stream 0, timescale not set
#   8%|▊         | 4/50 [01:25<14:51, 19.39s/it]stream 0, timescale not set
#  10%|█         | 5/50 [02:04<19:47, 26.38s/it]stream 0, timescale not set
#  12%|█▏        | 6/50 [02:33<19:54, 27.15s/it]stream 0, timescale not set
#  14%|█▍        | 7/50 [02:45<15:58, 22.30s/it]stream 0, timescale not set
#  16%|█▌        | 8/50 [02:47<11:08, 15.91s/it]stream 0, timescale not set
#  18%|█▊        | 9/50 [03:06<11:30, 16.83s/it]stream 0, timescale not set
#  20%|██        | 10/50 [03:15<09:35, 14.39s/it]stream 0, timescale not set
#  22%|██▏       | 11/50 [03:29<09:10, 14.12s/it]stream 0, timescale not set
#  24%|██▍       | 12/50 [03:33<07:09, 11.30s/it]stream 0, timescale not set
#  26%|██▌       | 13/50 [03:55<08:58, 14.55s/it]stream 0, timescale not set
#  28%|██▊       | 14/50 [04:13<09:11, 15.31s/it]stream 0, timescale not set
#  30%|███       | 15/50 [05:14<17:01, 29.19s/it]stream 0, timescale not set
#  32%|███▏      | 16/50 [05:30<14:14, 25.14s/it]stream 0, timescale not set
#  34%|███▍      | 17/50 [05:38<11:01, 20.05s/it]stream 0, timescale not set
#  36%|███▌      | 18/50 [05:56<10:27, 19.61s/it]stream 0, timescale not set
#  38%|███▊      | 19/50 [06:57<16:31, 32.00s/it]stream 0, timescale not set
#  40%|████      | 20/50 [07:10<13:09, 26.30s/it]stream 0, timescale not set
#  42%|████▏     | 21/50 [07:15<09:33, 19.78s/it]stream 0, timescale not set
#  44%|████▍     | 22/50 [07:26<08:00, 17.16s/it]stream 0, timescale not set
#  46%|████▌     | 23/50 [07:34<06:26, 14.31s/it]stream 0, timescale not set
#  50%|█████     | 25/50 [08:19<07:54, 18.97s/it]stream 0, timescale not set
#  52%|█████▏    | 26/50 [08:29<06:32, 16.35s/it]stream 0, timescale not set
#  54%|█████▍    | 27/50 [08:33<04:55, 12.83s/it]stream 0, timescale not set
#  56%|█████▌    | 28/50 [08:36<03:32,  9.68s/it]stream 0, timescale not set
#  58%|█████▊    | 29/50 [09:00<04:54, 14.04s/it]stream 0, timescale not set
#  60%|██████    | 30/50 [09:16<04:54, 14.71s/it]stream 0, timescale not set
#  62%|██████▏   | 31/50 [09:45<05:58, 18.88s/it]stream 0, timescale not set
#  64%|██████▍   | 32/50 [09:52<04:34, 15.27s/it]stream 0, timescale not set
#  66%|██████▌   | 33/50 [10:02<03:55, 13.86s/it]stream 0, timescale not set
#  68%|██████▊   | 34/50 [10:09<03:08, 11.79s/it]stream 0, timescale not set
#  70%|███████   | 35/50 [10:18<02:42, 10.83s/it]stream 0, timescale not set
#  72%|███████▏  | 36/50 [10:52<04:10, 17.86s/it]stream 0, timescale not set
#  74%|███████▍  | 37/50 [11:01<03:18, 15.25s/it]stream 0, timescale not set
#  76%|███████▌  | 38/50 [11:09<02:35, 12.97s/it]stream 0, timescale not set
#  78%|███████▊  | 39/50 [11:29<02:46, 15.14s/it]stream 0, timescale not set
#  80%|████████  | 40/50 [11:53<02:56, 17.67s/it]stream 0, timescale not set
#  82%|████████▏ | 41/50 [12:08<02:31, 16.88s/it]stream 0, timescale not set
#  84%|████████▍ | 42/50 [12:47<03:08, 23.54s/it]stream 0, timescale not set
#  88%|████████▊ | 44/50 [13:22<01:56, 19.48s/it]stream 0, timescale not set
#  90%|█████████ | 45/50 [13:37<01:30, 18.17s/it]stream 0, timescale not set
#  92%|█████████▏| 46/50 [13:52<01:08, 17.25s/it]stream 0, timescale not set
#  94%|█████████▍| 47/50 [13:57<00:40, 13.58s/it]stream 0, timescale not set
#  96%|█████████▌| 48/50 [14:09<00:25, 12.93s/it]stream 0, timescale not set
#  98%|█████████▊| 49/50 [27:53<04:16, 256.22s/it]stream 0, timescale not set
# 100%|██████████| 50/50 [28:24<00:00, 34.09s/it]
#   0%|          | 0/50 [00:00<?, ?it/s]stream 0, timescale not set
#   2%|▏         | 1/50 [00:01<01:28,  1.80s/it]stream 0, timescale not set
#   4%|▍         | 2/50 [00:14<06:28,  8.09s/it]stream 0, timescale not set
#   6%|▌         | 3/50 [00:42<13:41, 17.48s/it]stream 0, timescale not set
#   8%|▊         | 4/50 [00:49<10:11, 13.29s/it]stream 0, timescale not set
#  10%|█         | 5/50 [01:12<12:30, 16.67s/it]stream 0, timescale not set
#  12%|█▏        | 6/50 [02:00<20:00, 27.29s/it]stream 0, timescale not set
#  14%|█▍        | 7/50 [02:12<15:58, 22.30s/it]stream 0, timescale not set
#  16%|█▌        | 8/50 [02:44<17:52, 25.54s/it]stream 0, timescale not set
#  18%|█▊        | 9/50 [02:50<13:06, 19.19s/it]stream 0, timescale not set
#  20%|██        | 10/50 [03:07<12:21, 18.55s/it]stream 0, timescale not set
#  22%|██▏       | 11/50 [03:26<12:07, 18.66s/it]stream 0, timescale not set
#  24%|██▍       | 12/50 [03:46<12:13, 19.29s/it]stream 0, timescale not set
#  26%|██▌       | 13/50 [03:52<09:15, 15.02s/it]stream 0, timescale not set
#  28%|██▊       | 14/50 [07:00<40:30, 67.50s/it]stream 0, timescale not set
#  30%|███       | 15/50 [07:22<31:21, 53.74s/it]stream 0, timescale not set
#  34%|███▍      | 17/50 [07:54<19:12, 34.93s/it]stream 0, timescale not set
#  36%|███▌      | 18/50 [08:37<19:53, 37.31s/it]stream 0, timescale not set
#  38%|███▊      | 19/50 [08:50<15:34, 30.15s/it]stream 0, timescale not set
#  40%|████      | 20/50 [09:16<14:21, 28.71s/it]stream 0, timescale not set
#  42%|████▏     | 21/50 [09:47<14:16, 29.52s/it]stream 0, timescale not set
#  44%|████▍     | 22/50 [09:54<10:33, 22.64s/it]stream 0, timescale not set
#  46%|████▌     | 23/50 [10:09<09:08, 20.31s/it]stream 0, timescale not set
#  48%|████▊     | 24/50 [10:20<07:39, 17.68s/it]stream 0, timescale not set
#  50%|█████     | 25/50 [10:48<08:35, 20.62s/it]stream 0, timescale not set
#  52%|█████▏    | 26/50 [10:56<06:44, 16.87s/it]stream 0, timescale not set
#  54%|█████▍    | 27/50 [11:01<05:09, 13.44s/it]stream 0, timescale not set
#  56%|█████▌    | 28/50 [11:11<04:33, 12.42s/it]stream 0, timescale not set
#  58%|█████▊    | 29/50 [11:20<03:58, 11.35s/it]stream 0, timescale not set
#  60%|██████    | 30/50 [12:48<11:26, 34.34s/it]stream 0, timescale not set
#  62%|██████▏   | 31/50 [12:57<08:27, 26.69s/it]stream 0, timescale not set
#  64%|██████▍   | 32/50 [13:26<08:14, 27.49s/it]stream 0, timescale not set
#  66%|██████▌   | 33/50 [13:43<06:51, 24.22s/it]stream 0, timescale not set
#  68%|██████▊   | 34/50 [14:04<06:12, 23.26s/it]stream 0, timescale not set
#  70%|███████   | 35/50 [15:28<10:22, 41.51s/it]stream 0, timescale not set
#  72%|███████▏  | 36/50 [15:34<07:10, 30.75s/it]stream 0, timescale not set
#  74%|███████▍  | 37/50 [15:50<05:43, 26.43s/it]stream 0, timescale not set
#  76%|███████▌  | 38/50 [15:58<04:10, 20.91s/it]stream 0, timescale not set
#  78%|███████▊  | 39/50 [16:08<03:12, 17.53s/it]stream 0, timescale not set
#  80%|████████  | 40/50 [16:17<02:30, 15.06s/it]stream 0, timescale not set
#  82%|████████▏ | 41/50 [16:23<01:50, 12.33s/it]stream 0, timescale not set
#  84%|████████▍ | 42/50 [16:45<02:03, 15.38s/it]stream 0, timescale not set
#  86%|████████▌ | 43/50 [16:58<01:42, 14.61s/it]stream 0, timescale not set
#  88%|████████▊ | 44/50 [17:05<01:13, 12.22s/it]stream 0, timescale not set
#  90%|█████████ | 45/50 [17:26<01:14, 14.99s/it]stream 0, timescale not set
#  92%|█████████▏| 46/50 [17:53<01:14, 18.54s/it]stream 0, timescale not set
#  94%|█████████▍| 47/50 [18:22<01:04, 21.48s/it]stream 0, timescale not set
#  96%|█████████▌| 48/50 [18:47<00:45, 22.68s/it]stream 0, timescale not set
#  98%|█████████▊| 49/50 [18:59<00:19, 19.38s/it]stream 0, timescale not set
# 100%|██████████| 50/50 [19:15<00:00, 23.11s/it]

# %%
#Anomaly videos part2
# from tqdm.autonotebook import tqdm
path = '/home/iiitd/Anomaly_Dataset/Anomaly_Videos/Anomaly-Videos-Part-2'
result = '/home/iiitd/Dataset'

for i in os.listdir(path):
  p1 = os.path.join(path,i)
  r1 = os.path.join(result,i)
  if os.path.exists(r1):
            continue
  os.makedirs(r1,exist_ok = True)
  for j in tqdm(os.listdir(p1)):
    vid_path = os.path.join(p1,j)
    r2 = os.path.join(r1,j[:-4])
    os.makedirs(r2,exist_ok = True)
    for j, frame in enumerate((extract_frames(vid_path))):
      frame.save(os.path.join(r2, f"{j}.jpg"))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]stream 0, timescale not set
#   1%|          | 1/100 [00:06<11:28,  6.96s/it]stream 0, timescale not set
#   2%|▏         | 2/100 [00:20<18:02, 11.04s/it]stream 0, timescale not set
#   3%|▎         | 3/100 [00:32<18:20, 11.34s/it]stream 0, timescale not set
#   4%|▍         | 4/100 [00:41<16:55, 10.58s/it]stream 0, timescale not set
#   5%|▌         | 5/100 [00:55<18:34, 11.73s/it]stream 0, timescale not set
#   6%|▌         | 6/100 [01:10<20:13, 12.91s/it]stream 0, timescale not set
#   7%|▋         | 7/100 [02:28<52:49, 34.08s/it]stream 0, timescale not set
#   8%|▊         | 8/100 [02:32<37:44, 24.62s/it]stream 0, timescale not set
#   9%|▉         | 9/100 [02:36<27:06, 17.87s/it]stream 0, timescale not set
#  10%|█         | 10/100 [02:45<22:56, 15.30s/it]stream 0, timescale not set
#  11%|█         | 11/100 [02:59<21:52, 14.74s/it]stream 0, timescale not set
#  12%|█▏        | 12/100 [03:07<18:52, 12.87s/it]stream 0, timescale not set
#  13%|█▎        | 13/100 [04:12<41:22, 28.54s/it]stream 0, timescale not set
#  14%|█▍        | 14/100 [04:19<31:33, 22.02s/it]stream 0, timescale not set
#  15%|█▌        | 15/100 [04:27<25:11, 17.78s/it]stream 0, timescale not set
#  16%|█▌        | 16/100 [04:31<19:05, 13.64s/it]stream 0, timescale not set
#  17%|█▋        | 17/100 [04:36<15:30, 11.21s/it]stream 0, timescale not set
#  18%|█▊        | 18/100 [09:52<2:20:28, 102.79s/it]stream 0, timescale not set
#  19%|█▉        | 19/100 [09:57<1:39:02, 73.36s/it] stream 0, timescale not set
#  20%|██        | 20/100 [10:43<1:26:42, 65.03s/it]stream 0, timescale not set
#  21%|██        | 21/100 [10:56<1:05:23, 49.67s/it]stream 0, timescale not set
#  22%|██▏       | 22/100 [11:33<59:27, 45.74s/it]  stream 0, timescale not set
#  23%|██▎       | 23/100 [12:06<53:53, 42.00s/it]stream 0, timescale not set
#  24%|██▍       | 24/100 [12:21<42:40, 33.69s/it]stream 0, timescale not set
#  25%|██▌       | 25/100 [13:05<46:04, 36.85s/it]stream 0, timescale not set
#  26%|██▌       | 26/100 [13:25<39:12, 31.78s/it]stream 0, timescale not set
#  27%|██▋       | 27/100 [13:31<29:28, 24.23s/it]stream 0, timescale not set
#  28%|██▊       | 28/100 [13:40<23:31, 19.61s/it]stream 0, timescale not set
#  29%|██▉       | 29/100 [13:57<22:14, 18.79s/it]stream 0, timescale not set
#  30%|███       | 30/100 [14:10<20:00, 17.15s/it]stream 0, timescale not set
#  31%|███       | 31/100 [14:18<16:17, 14.17s/it]stream 0, timescale not set
#  32%|███▏      | 32/100 [14:46<20:56, 18.48s/it]stream 0, timescale not set
#  33%|███▎      | 33/100 [14:49<15:27, 13.85s/it]stream 0, timescale not set
#  34%|███▍      | 34/100 [15:29<23:45, 21.60s/it]stream 0, timescale not set
#  35%|███▌      | 35/100 [15:51<23:35, 21.78s/it]stream 0, timescale not set
#  36%|███▌      | 36/100 [16:26<27:18, 25.61s/it]stream 0, timescale not set
#  37%|███▋      | 37/100 [16:33<20:58, 19.98s/it]stream 0, timescale not set
#  38%|███▊      | 38/100 [16:40<16:53, 16.35s/it]stream 0, timescale not set
#  39%|███▉      | 39/100 [17:01<18:01, 17.73s/it]stream 0, timescale not set
#  40%|████      | 40/100 [17:18<17:27, 17.47s/it]stream 0, timescale not set
#  41%|████      | 41/100 [17:42<19:08, 19.47s/it]stream 0, timescale not set
#  42%|████▏     | 42/100 [17:44<13:42, 14.18s/it]stream 0, timescale not set
#  43%|████▎     | 43/100 [17:48<10:37, 11.18s/it]stream 0, timescale not set
#  44%|████▍     | 44/100 [17:58<09:54, 10.61s/it]stream 0, timescale not set
#  45%|████▌     | 45/100 [18:05<08:57,  9.78s/it]stream 0, timescale not set
#  46%|████▌     | 46/100 [18:08<06:56,  7.72s/it]stream 0, timescale not set
#  47%|████▋     | 47/100 [18:17<07:08,  8.08s/it]stream 0, timescale not set
#  48%|████▊     | 48/100 [18:33<08:56, 10.32s/it]stream 0, timescale not set
#  49%|████▉     | 49/100 [18:52<10:58, 12.92s/it]stream 0, timescale not set
#  50%|█████     | 50/100 [19:03<10:26, 12.53s/it]stream 0, timescale not set
#  51%|█████     | 51/100 [19:28<13:15, 16.24s/it]stream 0, timescale not set
#  52%|█████▏    | 52/100 [19:34<10:24, 13.02s/it]stream 0, timescale not set
#  53%|█████▎    | 53/100 [19:39<08:17, 10.59s/it]stream 0, timescale not set
#  54%|█████▍    | 54/100 [20:01<10:41, 13.94s/it]stream 0, timescale not set
#  55%|█████▌    | 55/100 [20:53<19:04, 25.43s/it]stream 0, timescale not set
#  56%|█████▌    | 56/100 [21:54<26:33, 36.22s/it]stream 0, timescale not set
#  57%|█████▋    | 57/100 [22:43<28:37, 39.95s/it]stream 0, timescale not set
#  58%|█████▊    | 58/100 [22:49<20:55, 29.90s/it]stream 0, timescale not set
#  59%|█████▉    | 59/100 [23:12<19:03, 27.89s/it]stream 0, timescale not set
#  60%|██████    | 60/100 [24:48<32:12, 48.32s/it]stream 0, timescale not set
#  61%|██████    | 61/100 [25:30<30:03, 46.25s/it]stream 0, timescale not set
#  62%|██████▏   | 62/100 [25:52<24:37, 38.88s/it]stream 0, timescale not set
#  63%|██████▎   | 63/100 [26:25<22:56, 37.21s/it]stream 0, timescale not set
#  64%|██████▍   | 64/100 [26:31<16:48, 28.01s/it]stream 0, timescale not set
#  65%|██████▌   | 65/100 [26:52<15:02, 25.80s/it]stream 0, timescale not set
#  66%|██████▌   | 66/100 [27:10<13:17, 23.47s/it]stream 0, timescale not set
#  67%|██████▋   | 67/100 [27:26<11:40, 21.21s/it]stream 0, timescale not set
#  68%|██████▊   | 68/100 [27:57<12:56, 24.26s/it]stream 0, timescale not set
#  69%|██████▉   | 69/100 [28:13<11:08, 21.58s/it]stream 0, timescale not set
#  70%|███████   | 70/100 [32:09<43:00, 86.03s/it]stream 0, timescale not set
#  71%|███████   | 71/100 [32:11<29:20, 60.72s/it]stream 0, timescale not set
#  72%|███████▏  | 72/100 [32:23<21:32, 46.15s/it]stream 0, timescale not set
#  73%|███████▎  | 73/100 [33:54<26:53, 59.74s/it]stream 0, timescale not set
#  74%|███████▍  | 74/100 [34:11<20:15, 46.77s/it]stream 0, timescale not set
#  75%|███████▌  | 75/100 [34:34<16:32, 39.70s/it]stream 0, timescale not set
#  76%|███████▌  | 76/100 [35:38<18:48, 47.01s/it]stream 0, timescale not set
#  77%|███████▋  | 77/100 [35:48<13:47, 36.00s/it]stream 0, timescale not set
#  78%|███████▊  | 78/100 [36:59<16:58, 46.28s/it]stream 0, timescale not set
#  79%|███████▉  | 79/100 [38:12<19:03, 54.45s/it]stream 0, timescale not set
#  80%|████████  | 80/100 [38:48<16:14, 48.71s/it]stream 0, timescale not set
#  81%|████████  | 81/100 [39:49<16:35, 52.37s/it]stream 0, timescale not set
#  82%|████████▏ | 82/100 [39:56<11:38, 38.78s/it]stream 0, timescale not set
#  83%|████████▎ | 83/100 [40:07<08:40, 30.63s/it]stream 0, timescale not set
#  84%|████████▍ | 84/100 [40:26<07:11, 26.96s/it]stream 0, timescale not set
#  85%|████████▌ | 85/100 [41:22<08:58, 35.93s/it]stream 0, timescale not set
#  86%|████████▌ | 86/100 [41:30<06:23, 27.38s/it]stream 0, timescale not set
#  87%|████████▋ | 87/100 [42:21<07:26, 34.36s/it]stream 0, timescale not set
#  88%|████████▊ | 88/100 [42:28<05:14, 26.17s/it]stream 0, timescale not set
#  89%|████████▉ | 89/100 [42:44<04:14, 23.17s/it]stream 0, timescale not set
#  90%|█████████ | 90/100 [42:58<03:25, 20.58s/it]stream 0, timescale not set
#  91%|█████████ | 91/100 [43:09<02:38, 17.65s/it]stream 0, timescale not set
#  92%|█████████▏| 92/100 [43:29<02:25, 18.24s/it]stream 0, timescale not set
#  93%|█████████▎| 93/100 [43:40<01:53, 16.18s/it]stream 0, timescale not set
#  94%|█████████▍| 94/100 [44:35<02:46, 27.73s/it]stream 0, timescale not set
#  95%|█████████▌| 95/100 [45:56<03:38, 43.75s/it]stream 0, timescale not set
#  96%|█████████▌| 96/100 [46:24<02:36, 39.11s/it]stream 0, timescale not set
#  97%|█████████▋| 97/100 [46:27<01:24, 28.14s/it]stream 0, timescale not set
#  98%|█████████▊| 98/100 [47:01<00:59, 29.96s/it]stream 0, timescale not set
#  99%|█████████▉| 99/100 [47:32<00:30, 30.38s/it]stream 0, timescale not set
# 100%|██████████| 100/100 [47:53<00:00, 28.74s/it]
#   0%|          | 0/50 [00:00<?, ?it/s]stream 0, timescale not set
#   2%|▏         | 1/50 [00:09<07:40,  9.39s/it]stream 0, timescale not set
#   4%|▍         | 2/50 [00:13<05:13,  6.54s/it]stream 0, timescale not set
#   6%|▌         | 3/50 [00:24<06:27,  8.25s/it]stream 0, timescale not set
#   8%|▊         | 4/50 [00:41<09:00, 11.74s/it]stream 0, timescale not set
#  10%|█         | 5/50 [01:18<15:36, 20.81s/it]stream 0, timescale not set
#  12%|█▏        | 6/50 [01:24<11:41, 15.94s/it]stream 0, timescale not set
#  14%|█▍        | 7/50 [01:27<08:18, 11.60s/it]stream 0, timescale not set
#  16%|█▌        | 8/50 [01:32<06:43,  9.60s/it]stream 0, timescale not set
#  18%|█▊        | 9/50 [01:42<06:40,  9.77s/it]stream 0, timescale not set
#  20%|██        | 10/50 [02:00<08:03, 12.08s/it]stream 0, timescale not set
#  22%|██▏       | 11/50 [02:14<08:22, 12.88s/it]stream 0, timescale not set
#  24%|██▍       | 12/50 [02:17<06:13,  9.82s/it]stream 0, timescale not set
#  26%|██▌       | 13/50 [02:32<07:04, 11.49s/it]stream 0, timescale not set
#  28%|██▊       | 14/50 [02:36<05:24,  9.02s/it]stream 0, timescale not set
#  30%|███       | 15/50 [02:48<05:46,  9.91s/it]stream 0, timescale not set
#  32%|███▏      | 16/50 [17:26<2:33:42, 271.24s/it]stream 0, timescale not set
#  34%|███▍      | 17/50 [17:37<1:46:13, 193.14s/it]stream 0, timescale not set
#  36%|███▌      | 18/50 [17:42<1:12:48, 136.53s/it]stream 0, timescale not set
#  38%|███▊      | 19/50 [17:53<51:02, 98.80s/it]   stream 0, timescale not set
#  40%|████      | 20/50 [18:18<38:20, 76.70s/it]stream 0, timescale not set
#  42%|████▏     | 21/50 [18:32<27:55, 57.76s/it]stream 0, timescale not set
#  44%|████▍     | 22/50 [18:38<19:47, 42.40s/it]stream 0, timescale not set
#  46%|████▌     | 23/50 [18:46<14:19, 31.85s/it]stream 0, timescale not set
#  48%|████▊     | 24/50 [20:38<24:13, 55.91s/it]stream 0, timescale not set
#  50%|█████     | 25/50 [20:41<16:42, 40.10s/it]stream 0, timescale not set
#  52%|█████▏    | 26/50 [20:49<12:10, 30.43s/it]stream 0, timescale not set
#  54%|█████▍    | 27/50 [21:04<09:52, 25.77s/it]stream 0, timescale not set
#  56%|█████▌    | 28/50 [21:08<07:05, 19.33s/it]stream 0, timescale not set
#  58%|█████▊    | 29/50 [21:31<07:07, 20.35s/it]stream 0, timescale not set
#  60%|██████    | 30/50 [21:41<05:47, 17.38s/it]stream 0, timescale not set
#  62%|██████▏   | 31/50 [22:10<06:33, 20.72s/it]stream 0, timescale not set
#  64%|██████▍   | 32/50 [22:15<04:50, 16.17s/it]stream 0, timescale not set
#  66%|██████▌   | 33/50 [22:40<05:19, 18.76s/it]stream 0, timescale not set
#  68%|██████▊   | 34/50 [22:47<04:03, 15.21s/it]stream 0, timescale not set
#  70%|███████   | 35/50 [23:08<04:13, 16.89s/it]stream 0, timescale not set
#  72%|███████▏  | 36/50 [23:27<04:06, 17.60s/it]stream 0, timescale not set
#  74%|███████▍  | 37/50 [23:50<04:09, 19.20s/it]stream 0, timescale not set
#  76%|███████▌  | 38/50 [24:07<03:43, 18.63s/it]stream 0, timescale not set
#  78%|███████▊  | 39/50 [24:15<02:47, 15.26s/it]stream 0, timescale not set
#  80%|████████  | 40/50 [24:17<01:53, 11.31s/it]stream 0, timescale not set
#  82%|████████▏ | 41/50 [24:33<01:55, 12.82s/it]stream 0, timescale not set
#  84%|████████▍ | 42/50 [24:35<01:15,  9.49s/it]stream 0, timescale not set
#  86%|████████▌ | 43/50 [24:39<00:54,  7.84s/it]stream 0, timescale not set
#  88%|████████▊ | 44/50 [24:43<00:40,  6.80s/it]stream 0, timescale not set
#  90%|█████████ | 45/50 [24:59<00:47,  9.43s/it]stream 0, timescale not set
#  92%|█████████▏| 46/50 [25:03<00:31,  7.93s/it]stream 0, timescale not set
#  94%|█████████▍| 47/50 [25:14<00:26,  8.77s/it]stream 0, timescale not set
#  96%|█████████▌| 48/50 [26:02<00:40, 20.50s/it]stream 0, timescale not set
#  98%|█████████▊| 49/50 [26:04<00:15, 15.02s/it]stream 0, timescale not set
# 100%|██████████| 50/50 [26:12<00:00, 31.45s/it]
#   0%|          | 0/50 [00:00<?, ?it/s]stream 0, timescale not set
#   2%|▏         | 1/50 [00:36<29:53, 36.60s/it]stream 0, timescale not set
#   4%|▍         | 2/50 [00:51<18:50, 23.55s/it]stream 0, timescale not set
#   6%|▌         | 3/50 [01:21<20:48, 26.57s/it]stream 0, timescale not set
#   8%|▊         | 4/50 [02:05<25:52, 33.75s/it]stream 0, timescale not set
#  10%|█         | 5/50 [02:24<21:18, 28.42s/it]stream 0, timescale not set
#  12%|█▏        | 6/50 [02:35<16:26, 22.41s/it]stream 0, timescale not set
#  14%|█▍        | 7/50 [02:41<12:06, 16.89s/it]stream 0, timescale not set
#  16%|█▌        | 8/50 [03:30<19:05, 27.27s/it]stream 0, timescale not set
#  18%|█▊        | 9/50 [04:57<31:20, 45.86s/it]stream 0, timescale not set
#  20%|██        | 10/50 [05:11<23:58, 35.96s/it]stream 0, timescale not set
#  22%|██▏       | 11/50 [06:20<30:01, 46.20s/it]stream 0, timescale not set
#  24%|██▍       | 12/50 [07:01<28:18, 44.71s/it]stream 0, timescale not set
#  26%|██▌       | 13/50 [07:53<28:54, 46.88s/it]stream 0, timescale not set
#  28%|██▊       | 14/50 [08:17<23:55, 39.86s/it]stream 0, timescale not set
#  30%|███       | 15/50 [08:23<17:15, 29.58s/it]stream 0, timescale not set
#  32%|███▏      | 16/50 [08:33<13:28, 23.78s/it]stream 0, timescale not set
#  34%|███▍      | 17/50 [09:02<13:59, 25.44s/it]stream 0, timescale not set
#  36%|███▌      | 18/50 [09:10<10:38, 19.96s/it]stream 0, timescale not set
#  38%|███▊      | 19/50 [09:37<11:24, 22.09s/it]stream 0, timescale not set
#  40%|████      | 20/50 [10:01<11:23, 22.77s/it]stream 0, timescale not set
#  42%|████▏     | 21/50 [10:42<13:43, 28.41s/it]stream 0, timescale not set
#  44%|████▍     | 22/50 [10:48<10:04, 21.58s/it]stream 0, timescale not set
#  46%|████▌     | 23/50 [11:05<09:03, 20.12s/it]stream 0, timescale not set
#  48%|████▊     | 24/50 [11:17<07:41, 17.75s/it]stream 0, timescale not set
#  50%|█████     | 25/50 [12:03<10:53, 26.16s/it]stream 0, timescale not set
#  52%|█████▏    | 26/50 [13:09<15:15, 38.14s/it]stream 0, timescale not set
#  54%|█████▍    | 27/50 [13:51<15:03, 39.28s/it]stream 0, timescale not set
#  56%|█████▌    | 28/50 [14:13<12:32, 34.22s/it]stream 0, timescale not set
#  58%|█████▊    | 29/50 [14:26<09:44, 27.84s/it]stream 0, timescale not set
#  60%|██████    | 30/50 [14:54<09:15, 27.78s/it]stream 0, timescale not set
#  62%|██████▏   | 31/50 [16:28<15:03, 47.57s/it]stream 0, timescale not set
#  64%|██████▍   | 32/50 [16:47<11:42, 39.04s/it]stream 0, timescale not set
#  66%|██████▌   | 33/50 [17:02<09:00, 31.80s/it]stream 0, timescale not set
#  68%|██████▊   | 34/50 [17:32<08:20, 31.26s/it]stream 0, timescale not set
#  70%|███████   | 35/50 [18:08<08:12, 32.82s/it]stream 0, timescale not set
#  72%|███████▏  | 36/50 [18:28<06:46, 29.00s/it]stream 0, timescale not set
#  74%|███████▍  | 37/50 [18:37<04:57, 22.85s/it]stream 0, timescale not set
#  76%|███████▌  | 38/50 [21:22<13:05, 65.45s/it]stream 0, timescale not set
#  78%|███████▊  | 39/50 [21:37<09:15, 50.49s/it]stream 0, timescale not set
#  80%|████████  | 40/50 [22:01<07:05, 42.51s/it]stream 0, timescale not set
#  82%|████████▏ | 41/50 [22:16<05:08, 34.24s/it]stream 0, timescale not set
#  84%|████████▍ | 42/50 [26:03<12:16, 92.03s/it]stream 0, timescale not set
#  86%|████████▌ | 43/50 [26:44<08:57, 76.84s/it]stream 0, timescale not set
#  88%|████████▊ | 44/50 [26:49<05:32, 55.35s/it]stream 0, timescale not set
#  90%|█████████ | 45/50 [27:09<03:43, 44.68s/it]stream 0, timescale not set
#  92%|█████████▏| 46/50 [27:28<02:28, 37.01s/it]stream 0, timescale not set
#  94%|█████████▍| 47/50 [27:36<01:24, 28.18s/it]stream 0, timescale not set
#  96%|█████████▌| 48/50 [27:44<00:44, 22.08s/it]stream 0, timescale not set
#  98%|█████████▊| 49/50 [28:26<00:27, 27.99s/it]stream 0, timescale not set
# 100%|██████████| 50/50 [28:39<00:00, 34.40s/it]

# %%
#Normal class
# from tqdm.autonotebook import tqdm
path = '/home/iiitd/Anomaly_Dataset/Anomaly_Videos/Normal-Videos-Part-1'
result = '/home/iiitd/Dataset/normal'

for i in tqdm(os.listdir(path)):
  p1 = os.path.join(path,i)
  r1 = os.path.join(result,i[:-4])
  if os.path.exists(r1):
            continue
  os.makedirs(r1,exist_ok = True)
  for k, frame in enumerate((extract_frames(p1))):
    frame.save(os.path.join(r1, f"{k}.jpg"))
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]stream 0, timescale not set
#   1%|          | 1/150 [00:19<48:36, 19.57s/it]stream 0, timescale not set
#   1%|▏         | 2/150 [00:30<35:01, 14.20s/it]stream 0, timescale not set
#   2%|▏         | 3/150 [00:38<28:24, 11.60s/it]stream 0, timescale not set
#   3%|▎         | 4/150 [00:50<28:18, 11.63s/it]stream 0, timescale not set
#   3%|▎         | 5/150 [01:01<27:37, 11.43s/it]stream 0, timescale not set
#   4%|▍         | 6/150 [01:03<19:48,  8.25s/it]stream 0, timescale not set
#   5%|▍         | 7/150 [01:06<16:00,  6.71s/it]stream 0, timescale not set
#   5%|▌         | 8/150 [01:12<15:05,  6.38s/it]stream 0, timescale not set
#   6%|▌         | 9/150 [01:57<43:24, 18.47s/it]stream 0, timescale not set
#   7%|▋         | 10/150 [02:00<31:48, 13.63s/it]stream 0, timescale not set
#   7%|▋         | 11/150 [02:10<29:23, 12.69s/it]stream 0, timescale not set
#   8%|▊         | 12/150 [02:38<39:32, 17.19s/it]stream 0, timescale not set
#   9%|▊         | 13/150 [03:01<43:17, 18.96s/it]stream 0, timescale not set
#   9%|▉         | 14/150 [03:12<37:26, 16.52s/it]stream 0, timescale not set
#  10%|█         | 15/150 [03:23<33:47, 15.02s/it]stream 0, timescale not set
#  11%|█         | 16/150 [03:33<30:03, 13.46s/it]stream 0, timescale not set
#  11%|█▏        | 17/150 [03:44<27:43, 12.51s/it]stream 0, timescale not set
#  12%|█▏        | 18/150 [03:54<25:54, 11.78s/it]stream 0, timescale not set
#  13%|█▎        | 19/150 [04:22<36:41, 16.81s/it]stream 0, timescale not set
#  13%|█▎        | 20/150 [04:29<29:57, 13.83s/it]stream 0, timescale not set
#  14%|█▍        | 21/150 [04:40<27:51, 12.96s/it]stream 0, timescale not set
#  15%|█▍        | 22/150 [05:11<39:15, 18.41s/it]stream 0, timescale not set
#  15%|█▌        | 23/150 [05:15<29:29, 13.94s/it]stream 0, timescale not set
#  16%|█▌        | 24/150 [05:16<21:34, 10.27s/it]stream 0, timescale not set
#  17%|█▋        | 25/150 [05:59<41:28, 19.91s/it]stream 0, timescale not set
#  17%|█▋        | 26/150 [06:04<31:53, 15.43s/it]stream 0, timescale not set
#  18%|█▊        | 27/150 [06:20<32:12, 15.71s/it]stream 0, timescale not set
#  19%|█▊        | 28/150 [18:12<7:36:50, 224.68s/it]stream 0, timescale not set
#  19%|█▉        | 29/150 [18:18<5:20:41, 159.02s/it]stream 0, timescale not set
#  20%|██        | 30/150 [18:24<3:46:01, 113.01s/it]stream 0, timescale not set
#  21%|██        | 31/150 [18:31<2:41:11, 81.28s/it] stream 0, timescale not set
#  21%|██▏       | 32/150 [18:35<1:54:15, 58.09s/it]stream 0, timescale not set
#  22%|██▏       | 33/150 [18:39<1:21:36, 41.85s/it]stream 0, timescale not set
#  23%|██▎       | 34/150 [18:58<1:07:55, 35.13s/it]stream 0, timescale not set
#  23%|██▎       | 35/150 [20:55<1:54:21, 59.67s/it]stream 0, timescale not set
#  24%|██▍       | 36/150 [20:58<1:20:52, 42.56s/it]stream 0, timescale not set
#  25%|██▍       | 37/150 [21:21<1:09:16, 36.79s/it]stream 0, timescale not set
#  25%|██▌       | 38/150 [21:32<54:09, 29.01s/it]  stream 0, timescale not set
#  26%|██▌       | 39/150 [21:37<40:23, 21.83s/it]stream 0, timescale not set
#  27%|██▋       | 40/150 [21:51<35:37, 19.43s/it]stream 0, timescale not set
#  27%|██▋       | 41/150 [21:53<26:02, 14.33s/it]stream 0, timescale not set
#  28%|██▊       | 42/150 [33:10<6:23:38, 213.13s/it]stream 0, timescale not set
#  29%|██▊       | 43/150 [33:14<4:27:44, 150.13s/it]stream 0, timescale not set
#  29%|██▉       | 44/150 [33:20<3:09:10, 107.08s/it]stream 0, timescale not set
#  30%|███       | 45/150 [33:28<2:15:15, 77.29s/it] stream 0, timescale not set
#  31%|███       | 46/150 [35:06<2:24:53, 83.60s/it]stream 0, timescale not set
#  31%|███▏      | 47/150 [35:13<1:43:44, 60.44s/it]stream 0, timescale not set
#  32%|███▏      | 48/150 [35:23<1:16:57, 45.27s/it]stream 0, timescale not set
#  33%|███▎      | 49/150 [35:30<56:52, 33.79s/it]  stream 0, timescale not set
#  33%|███▎      | 50/150 [35:32<40:49, 24.49s/it]stream 0, timescale not set
#  34%|███▍      | 51/150 [35:35<29:48, 18.06s/it]stream 0, timescale not set
#  35%|███▍      | 52/150 [35:44<24:49, 15.20s/it]stream 0, timescale not set
#  35%|███▌      | 53/150 [35:55<22:35, 13.97s/it]stream 0, timescale not set
#  36%|███▌      | 54/150 [36:37<35:46, 22.35s/it]stream 0, timescale not set
#  37%|███▋      | 55/150 [36:49<30:35, 19.32s/it]stream 0, timescale not set
#  37%|███▋      | 56/150 [37:26<38:18, 24.45s/it]stream 0, timescale not set
#  38%|███▊      | 57/150 [38:00<42:21, 27.33s/it]stream 0, timescale not set
#  39%|███▊      | 58/150 [38:06<32:05, 20.93s/it]stream 0, timescale not set
#  39%|███▉      | 59/150 [38:15<26:16, 17.33s/it]stream 0, timescale not set
#  40%|████      | 60/150 [39:30<52:08, 34.76s/it]stream 0, timescale not set
#  41%|████      | 61/150 [39:34<37:45, 25.46s/it]stream 0, timescale not set
#  41%|████▏     | 62/150 [39:40<29:00, 19.77s/it]stream 0, timescale not set
#  42%|████▏     | 63/150 [39:55<26:17, 18.13s/it]stream 0, timescale not set
#  43%|████▎     | 64/150 [40:08<23:58, 16.72s/it]stream 0, timescale not set
#  43%|████▎     | 65/150 [40:12<18:16, 12.90s/it]stream 0, timescale not set
#  44%|████▍     | 66/150 [40:30<20:08, 14.39s/it]stream 0, timescale not set
#  45%|████▍     | 67/150 [41:36<41:12, 29.79s/it]stream 0, timescale not set
#  45%|████▌     | 68/150 [42:00<38:36, 28.25s/it]stream 0, timescale not set
#  46%|████▌     | 69/150 [42:40<42:51, 31.74s/it]stream 0, timescale not set
#  47%|████▋     | 70/150 [42:50<33:25, 25.07s/it]stream 0, timescale not set
#  47%|████▋     | 71/150 [43:00<27:11, 20.65s/it]stream 0, timescale not set
#  48%|████▊     | 72/150 [43:05<20:33, 15.82s/it]stream 0, timescale not set
#  49%|████▊     | 73/150 [43:11<16:49, 13.12s/it]stream 0, timescale not set
#  49%|████▉     | 74/150 [43:19<14:33, 11.49s/it]stream 0, timescale not set
#  50%|█████     | 75/150 [43:31<14:25, 11.54s/it]stream 0, timescale not set
#  51%|█████     | 76/150 [43:44<14:40, 11.90s/it]stream 0, timescale not set
#  51%|█████▏    | 77/150 [44:38<30:04, 24.72s/it]stream 0, timescale not set
#  52%|█████▏    | 78/150 [44:55<26:56, 22.45s/it]stream 0, timescale not set
#  53%|█████▎    | 79/150 [44:58<19:37, 16.58s/it]stream 0, timescale not set
#  53%|█████▎    | 80/150 [45:01<14:23, 12.33s/it]stream 0, timescale not set
#  54%|█████▍    | 81/150 [45:06<11:48, 10.27s/it]stream 0, timescale not set
#  55%|█████▍    | 82/150 [45:21<13:13, 11.67s/it]stream 0, timescale not set
#  55%|█████▌    | 83/150 [45:28<11:34, 10.36s/it]stream 0, timescale not set
#  56%|█████▌    | 84/150 [45:44<13:15, 12.05s/it]stream 0, timescale not set
#  57%|█████▋    | 85/150 [46:10<17:32, 16.20s/it]stream 0, timescale not set
#  57%|█████▋    | 86/150 [47:08<30:43, 28.81s/it]stream 0, timescale not set
#  58%|█████▊    | 87/150 [47:10<21:44, 20.71s/it]stream 0, timescale not set
#  59%|█████▊    | 88/150 [47:12<15:24, 14.91s/it]stream 0, timescale not set
#  59%|█████▉    | 89/150 [47:17<12:23, 12.19s/it]stream 0, timescale not set
#  60%|██████    | 90/150 [47:51<18:39, 18.65s/it]stream 0, timescale not set
#  61%|██████    | 91/150 [48:24<22:34, 22.96s/it]stream 0, timescale not set
#  61%|██████▏   | 92/150 [48:58<25:21, 26.23s/it]stream 0, timescale not set
#  62%|██████▏   | 93/150 [49:07<20:00, 21.06s/it]stream 0, timescale not set
#  63%|██████▎   | 94/150 [49:25<18:45, 20.09s/it]stream 0, timescale not set
#  63%|██████▎   | 95/150 [49:41<17:16, 18.84s/it]stream 0, timescale not set
#  64%|██████▍   | 96/150 [50:08<19:16, 21.42s/it]stream 0, timescale not set
#  65%|██████▍   | 97/150 [50:22<17:01, 19.28s/it]stream 0, timescale not set
#  65%|██████▌   | 98/150 [50:28<13:06, 15.12s/it]stream 0, timescale not set
#  66%|██████▌   | 99/150 [50:32<09:54, 11.66s/it]stream 0, timescale not set
#  67%|██████▋   | 100/150 [50:46<10:33, 12.66s/it]stream 0, timescale not set
#  67%|██████▋   | 101/150 [51:21<15:46, 19.31s/it]stream 0, timescale not set
#  68%|██████▊   | 102/150 [51:24<11:28, 14.34s/it]stream 0, timescale not set
#  69%|██████▊   | 103/150 [51:25<08:08, 10.39s/it]stream 0, timescale not set
#  69%|██████▉   | 104/150 [51:30<06:44,  8.79s/it]stream 0, timescale not set
#  70%|███████   | 105/150 [51:50<09:06, 12.14s/it]stream 0, timescale not set
#  71%|███████   | 106/150 [51:57<07:43, 10.52s/it]stream 0, timescale not set
#  71%|███████▏  | 107/150 [52:10<07:58, 11.14s/it]stream 0, timescale not set
#  72%|███████▏  | 108/150 [52:27<09:08, 13.07s/it]stream 0, timescale not set
#  73%|███████▎  | 109/150 [52:42<09:12, 13.47s/it]stream 0, timescale not set
#  73%|███████▎  | 110/150 [56:52<56:22, 84.56s/it]stream 0, timescale not set
#  74%|███████▍  | 111/150 [57:03<40:37, 62.51s/it]stream 0, timescale not set
#  75%|███████▍  | 112/150 [57:15<29:54, 47.23s/it]stream 0, timescale not set
#  75%|███████▌  | 113/150 [57:20<21:24, 34.71s/it]stream 0, timescale not set
#  76%|███████▌  | 114/150 [57:26<15:42, 26.19s/it]stream 0, timescale not set
#  77%|███████▋  | 115/150 [58:06<17:37, 30.22s/it]stream 0, timescale not set
#  77%|███████▋  | 116/150 [58:48<19:09, 33.80s/it]stream 0, timescale not set
#  78%|███████▊  | 117/150 [59:19<18:05, 32.91s/it]stream 0, timescale not set
#  79%|███████▊  | 118/150 [59:34<14:45, 27.67s/it]stream 0, timescale not set
#  79%|███████▉  | 119/150 [59:39<10:42, 20.72s/it]stream 0, timescale not set
#  80%|████████  | 120/150 [1:00:39<16:16, 32.54s/it]stream 0, timescale not set
#  81%|████████  | 121/150 [1:01:00<14:04, 29.12s/it]stream 0, timescale not set
#  81%|████████▏ | 122/150 [1:01:08<10:31, 22.57s/it]stream 0, timescale not set
#  82%|████████▏ | 123/150 [1:01:38<11:15, 25.01s/it]stream 0, timescale not set
#  83%|████████▎ | 124/150 [1:01:40<07:50, 18.11s/it]stream 0, timescale not set
#  83%|████████▎ | 125/150 [1:02:06<08:33, 20.52s/it]stream 0, timescale not set
#  84%|████████▍ | 126/150 [1:02:13<06:34, 16.43s/it]stream 0, timescale not set
#  85%|████████▍ | 127/150 [1:02:27<06:00, 15.66s/it]stream 0, timescale not set
#  85%|████████▌ | 128/150 [1:02:38<05:10, 14.12s/it]stream 0, timescale not set
#  86%|████████▌ | 129/150 [1:02:49<04:40, 13.35s/it]stream 0, timescale not set
#  87%|████████▋ | 130/150 [1:02:55<03:38, 10.93s/it]stream 0, timescale not set
#  87%|████████▋ | 131/150 [1:03:06<03:30, 11.06s/it]stream 0, timescale not set
#  88%|████████▊ | 132/150 [1:03:14<03:00, 10.03s/it]stream 0, timescale not set
#  89%|████████▊ | 133/150 [1:03:33<03:41, 13.00s/it]stream 0, timescale not set
#  89%|████████▉ | 134/150 [1:04:09<05:17, 19.83s/it]stream 0, timescale not set
#  90%|█████████ | 135/150 [1:04:13<03:47, 15.14s/it]stream 0, timescale not set
#  91%|█████████ | 136/150 [1:04:34<03:54, 16.78s/it]stream 0, timescale not set
#  91%|█████████▏| 137/150 [1:04:42<03:02, 14.01s/it]stream 0, timescale not set
#  92%|█████████▏| 138/150 [1:05:43<05:39, 28.28s/it]stream 0, timescale not set
#  93%|█████████▎| 139/150 [1:05:54<04:14, 23.13s/it]stream 0, timescale not set
#  93%|█████████▎| 140/150 [1:05:59<02:55, 17.58s/it]stream 0, timescale not set
#  94%|█████████▍| 141/150 [1:06:15<02:33, 17.05s/it]stream 0, timescale not set
#  95%|█████████▍| 142/150 [1:06:20<01:48, 13.56s/it]stream 0, timescale not set
#  95%|█████████▌| 143/150 [1:07:07<02:45, 23.59s/it]stream 0, timescale not set
#  96%|█████████▌| 144/150 [1:07:14<01:51, 18.52s/it]stream 0, timescale not set
#  97%|█████████▋| 145/150 [1:09:06<03:53, 46.74s/it]stream 0, timescale not set
#  97%|█████████▋| 146/150 [1:09:15<02:21, 35.27s/it]stream 0, timescale not set
#  98%|█████████▊| 147/150 [1:09:20<01:18, 26.27s/it]stream 0, timescale not set
#  99%|█████████▊| 148/150 [1:10:18<01:11, 35.71s/it]stream 0, timescale not set
#  99%|█████████▉| 149/150 [1:10:25<00:27, 27.14s/it]stream 0, timescale not set
# 100%|██████████| 150/150 [1:10:44<00:00, 28.29s/it]

# %%
path = '/home/iiitd/Dataset'
res = '/home/iiitd/crime'
#Number
seq_length = 16

def preprocess_data(seq_length,path,res):
  dir = os.listdir(path)
  for i in tqdm(dir):
      p1 = os.path.join(path,i)
      r1 = os.path.join(res,i)
      os.makedirs(r1,exist_ok = True)
      for j in os.listdir(p1):
          p2 = os.path.join(p1,j)
          r2 = os.path.join(r1,j)
          l = 0
          skip_length = int(len(os.listdir(p2))/seq_length)
          for m in range(10):
              k = m
              while(l!=seq_length):

                  p3 = os.path.join(p2,str(k) + ".jpg")
                  try:
                      img = cv2.imread(p3)
                      img = cv2.resize(img,(128,128))
                  except:
                      print(p3)
                  if(k==0):
                      img1 = img
                  else:
                      img1 = np.append(img1,img,axis = 1)
                  k = k+skip_length
                  l = l+1    
              cv2.imwrite(r2 + str(m)+".jpg",img1)

# %%
import numpy as np
preprocess_data(seq_length,path,res)
# Out:
# 100%|██████████| 8/8 [01:47<00:00, 13.45s/it]
